# %%
from reporting_functions.report_functions import plot_analysis, stats_report

# %%
stats_report('../ale-gpt4migrate-tests/scripts/faker_grievance_issues.csv')
# Out:
#                                   entry_count data_type  null_count  \
# grievance_number                         1000     int64           0
# gdc_id                                   1000     int64           0
# inmate_name                              1000    object           0
# facility_location_cd                     1000    object           0
# facility                                 1000    object           0
# grievance_type                           1000    object           0
# grievance_date                           1000    object           0
# form_received_date                       1000    object           0
# expedited                                1000    object           0
# grievance_category                       1000    object           0
# complaint_or_resolution                  1000    object           0
# stage_cd                                 1000     int64           0
# informal_status_cd                       1000     int64           0
# ...

# %%
initial_analysis('../ale-gpt4migrate-tests/scripts/faker_grievance_issues.csv')
