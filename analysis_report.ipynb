# %%
import pandas as pd
from report_functions import initial_analysis, eda_report

# %%
eda_report('../gun_deaths_us/gun_data.csv')
# Out:
#                   entry_count data_type  null_count         mean        std  \
# year                   529233     int64           0  2013.480724   4.359197
# month                  529233     int64           0     6.569454   3.400949
# intent                 529233    object          27          NaN        NaN
# police                 529233     int64           0     0.012824   0.112516
# victim_sex             529233    object           0          NaN        NaN
# victim_age             529233   float64          77    42.918429  19.485696
# victim_race            529233    object           0          NaN        NaN
# place                  529233    object        6660          NaN        NaN
# victim_education       529233    object       13208          NaN        NaN
#
#                      min     25%     50%     75%     max
# year              2006.0  2010.0  2014.0  2017.0  2020.0
# month                1.0     4.0     7.0     9.0    12.0
# ...

# %%
initial_analysis('../gun_deaths_us/gun_data.csv', 2)
