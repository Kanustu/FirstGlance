# %%
from faker import Faker
import pandas as pd
import random

# %%
fake = Faker()
num_columns = 2
num_rows = 1000

# %%
num_creation = fake.random_number(digits=random.randint(4,5))

# %%
data = {}
for x in range(num_columns):
    column_name = x
    data[column_name] = [fake.random_number(digits=5) for x in range(num_rows)]

# %%
dataframe = pd.DataFrame(data)

# %%
dataframe.to_csv('example.csv', index=False)

# %%
from report_functions import plot_analysis, stats_report

# %%
plot_analysis('example.csv')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plot_analysis('example.csv')
#
# File ~/projects/analysis_reporting/FirstGlance/report_functions.py:180, in plot_analysis(csv)
#     178 data = data_input(csv)
#     179 print('\n')
# --> 180 create_subplots(data, 'boxplot')
#     181 print('\n\n')
#     182 create_subplots(data, 'histplot')
#
# File ~/projects/analysis_reporting/FirstGlance/report_functions.py:29, in create_subplots(data, plot_type)
#      27 col = i % num_cols
#      28 if plot_type == 'boxplot':
# ---> 29     sns.boxplot(x=data[column], ax=axes[row, col])
#      30 elif plot_type == 'histplot':
#      31     sns.histplot(x=data[column], ax=axes[row, col])
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
